# %%
import text_metrics.base
from text_metrics.resource_pool import rp as default_rp

# 1. El texto que quieres analizar
texto_pix = "fiz um pix mas o meu dinheiro nao caiu na conta"

# 2. Creamos el objeto de texto que NILC-Metrix entiende
t = text_metrics.base.Text(texto_pix)

# 3. Ejecutamos el motor de métricas
# Esto usará tu base de datos local y NLPNet automáticamente
print("Analizando texto... por favor espera.")
try:
    results = text_metrics.CMP_METRICS.values_for_text(t, default_rp).as_flat_dict()

    # 4. Imprimimos los resultados COMPLETOS
    print("\n--- LISTADO COMPLETO DE MÉTRICAS ---")
    all_metrics = list(results.items())
    for metric, value in all_metrics:
        print(f"{metric}: {value}")
    
    print(f"\nTotal de métricas procesadas: {len(all_metrics)}")

except Exception as e:
    print(f"Error durante el análisis: {e}")
# Out:
# Analizando texto... por favor espera.
#
# --- LISTADO COMPLETO DE MÉTRICAS ---
# adjective_ratio: 0.09091
# adverbs: 0.0
# content_words: 0.54545
# flesch: 114.61545
# function_words: 0.45455
# sentences_per_paragraph: 1.0
# syllables_per_content_word: 1.83333
# words_per_sentence: 11.0
# noun_ratio: 0.27273
# paragraphs: 1
# sentences: 1
# words: 11
# pronoun_ratio: 0.09091
# verbs: 0.18182
# logic_operators: 0.0
# and_ratio: 0.0
# if_ratio: 0.0
# or_ratio: 0.0
# negation_ratio: 0.0
# cw_freq: 58168.0
# cw_freq_brwac: 4.134
# cw_freq_bra: 4.4125
# min_cw_freq: 210.0
# min_cw_freq_brwac: 0.985
# min_freq_brwac: 0.985
# min_cw_freq_bra: 2.7
# min_freq_bra: 2.7
# freq_brwac: 5.30509
# freq_bra: 5.38164
# hypernyms_verbs: 0.0
# personal_pronouns: 0.0
# ttr: 1.0
# words_before_main_verb: 0
# conn_ratio: 0.09091
# add_neg_conn_ratio: 0.09091
# add_pos_conn_ratio: 0.0
# cau_neg_conn_ratio: 0.0
# cau_pos_conn_ratio: 0.0
# log_neg_conn_ratio: 0.0
# log_pos_conn_ratio: 0.0
# tmp_neg_conn_ratio: 0.0
# tmp_pos_conn_ratio: 0.0
# adjectives_ambiguity: 0
# adverbs_ambiguity: 0
# nouns_ambiguity: 2.5
# verbs_ambiguity: 19.0
# adj_arg_ovl: 0
# arg_ovl: 0
# adj_stem_ovl: 0
# stem_ovl: 0
# adj_cw_ovl: 0
# adjacent_refs: 0
# anaphoric_refs: 0
# mean_noun_phrase: 3.0
#
# Total de métricas procesadas: 54
